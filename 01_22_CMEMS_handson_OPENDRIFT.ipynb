# %% [markdown]
# <img src="https://i.imgur.com/lemJ6qf.png" align=center>

# %% [markdown]
# # CMEMS_2 SAIL ARIANE / OPENDRIFT
# ## SAIL THROUGH THE INDONESIAN THROUGHFLOW with OpenDrift, a lagrangian particles trajectories tool

# %% [markdown]
# OpenDrift is a software package for modeling the trajectories and fate of objects or substances drifting in the ocean, or even in the atmosphere.
# The aim of this exercise is to follow the trajectories of particules sed in the Indonesian throughflow over a period to study where they are likely to go and land. We will use the Global Ocean Physics Analysis and Forecast product to do so.

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Run" and select "Run All Above Selected Cell".<br><br>
# **General Note 3**: Download the file with all dependencies and unzip while preserving file structure in the same directory as the notebook: [Download dependency file ARIANE](https://atlas.mercator-ocean.fr/s/xLrmSTgymBgAirs)<br>
# ***

# %% [markdown]
# First, the notebook must be set up with all the necessary tools available from the Jupyter Notebook Ecosystem.
#
# | Module name | Description |
# | :---: | :---|
# | **datetime** | [Datetime](https://docs.python.org/fr/3/library/datetime.html) allows managing dates and times variables |
# | **numpy** | [NumPy](https://numpy.org/) allows carrying out scientific computing with Python and managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) handles netCDF files in an intuitive and interactive way. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python numerical plotting library |
# | **cartopy** |[Cartopy](https://scitools.org.uk/cartopy/docs/latest/) is a library for plotting 2D data on maps. |
# | **opendrift** |[OpenDrift](https://opendrift.github.io/) models the trajectories of objects drifting in the ocean|

# %%
from datetime import datetime, timedelta
import numpy as np 
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.readers import reader_shape
from opendrift.models.oceandrift import OceanDrift
import cartopy.io.shapereader as shpreader
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import xarray as xr

# %% [markdown]
# The input file has already been prepared for the exercise. It contains the current variables (x and y direction)for the period we intend to study : June to August 2015. Let's have a look at it.

# %%
path_file = 'ARIANE/DATA/glorys12v1_landmask_v3.nc'
file = xr.open_dataset(path_file)
print(file)
# Out:
# <xarray.Dataset>
# Dimensions:               (depth: 1, latitude: 481, longitude: 841, time: 61)
# Coordinates:
#   * depth                 (depth) float32 0.494
#   * latitude              (latitude) float32 -20.0 -19.92 -19.83 ... 19.92 20.0
#   * longitude             (longitude) float32 90.0 90.08 90.17 ... 159.9 160.0
#   * time                  (time) datetime64[ns] 2015-06-01T12:00:00 ... 2015-...
# Data variables:
#     land_binary_mask      (time, latitude, longitude) float64 ...
#     x_sea_water_velocity  (time, depth, latitude, longitude) float32 ...
#     y_sea_water_velocity  (time, depth, latitude, longitude) float32 ...
# Attributes: (12/26)
#     CDI:                                Climate Data Interface version 1.9.8 ...
#     Conventions:                        CF-1.4
#     history:                            Thu Apr  1 17:49:14 2021: ncks -x -v ...
#     source:                             MERCATOR GLORYS12V1
#     institution:                        MERCATOR OCEAN
#     title:                              daily mean fields from Global Ocean P...
#     ...                                 ...
#     FROM_ORIGINAL_FILE__latitude_max:   90.0
#     z_min:                              0.494025
#     z_max:                              5727.917
#     _CoordSysBuilder:                   ucar.nc2.dataset.conv.CF1Convention
#     NCO:                                netCDF Operators version 4.7.5 (Homep...
#     CDO:                                Climate Data Operators version 1.9.8 ...

# %% [markdown]
# We will now initialize OpenDrift  with this file :

# %%
o = OceanDrift(loglevel=0)  # Set loglevel to 0 for debug information

reader_analysis = reader_netCDF_CF_generic.Reader("ARIANE/DATA/glorys12v1_landmask_v3.nc")

shpfilename = shpreader.natural_earth(resolution='110m',
                category='cultural',
                name='admin_0_countries')
reader_natural = reader_shape.Reader.from_shpfiles(shpfilename)

o.add_reader([reader_natural, reader_analysis])
o.set_config('general:use_auto_landmask', False)  # Disabling the automatic GSHHG landmask
o.set_config('general:coastline_action', 'stranding')
print("reader init ok")
# Out:
# 08:09:29 DEBUG   opendrift.models.basemodel: Adding 17 config items from basemodel
# 08:09:29 DEBUG   opendrift.models.basemodel: Adding 4 config items from basemodel
# 08:09:29 DEBUG   opendrift.models.basemodel: Adding 34 config items from basemodel
# 08:09:29 INFO    opendrift.models.basemodel: OpenDriftSimulation initialised (version 1.5.6)
# 08:09:29 DEBUG   opendrift.models.basemodel: Adding 13 config items from oceandrift
# 08:09:29 DEBUG   opendrift.models.basemodel:   Overwriting config item seed:z
# 08:09:29 INFO    opendrift.readers.reader_netCDF_CF_generic: Opening dataset: ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:29 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Finding coordinate variables.
# 08:09:29 INFO    opendrift.readers.reader_netCDF_CF_generic: Grid coordinates are detected, but proj4 string not given: assuming latlong
# 08:09:29 DEBUG   opendrift.readers.basereader.variables: Setting buffer size 49 for reader ARIANE/DATA/glorys12v1_landmask_v3.nc, assuming a maximum average speed of 5 m/s.
# 08:09:29 INFO    opendrift.readers.basereader: Variable x_sea_water_velocity will be rotated from eastward_sea_water_velocity
# 08:09:29 INFO    opendrift.readers.basereader: Variable y_sea_water_velocity will be rotated from northward_sea_water_velocity
# 08:09:29 DEBUG   opendrift.readers.reader_shape: Reading shapefile: /home/efouchet/.local/share/cartopy/shapefiles/natural_earth/cultural/ne_110m_admin_0_countries.shp
# 08:09:29 INFO    opendrift.readers.reader_shape: Pre-processing 177 geometries
# 08:09:29 DEBUG   opendrift.models.basemodel: Added reader shape
# 08:09:29 DEBUG   opendrift.readers.basereader.variables: Setting buffer size 12 for reader ARIANE/DATA/glorys12v1_landmask_v3.nc, assuming a maximum average speed of 1 m/s.
# 08:09:29 DEBUG   opendrift.models.basemodel: Added reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# reader init ok

# %% [markdown]
# We now initialize the particules. You can adapt the following cell to define the location of the particules to seed. Change the variables lon/lat min/max and nb_points to define the geographical extent and density of particules. With another input file, you may also change the starting date.

# %%
seed_time = datetime(2015,6,1)

lons=[]
lats=[]

lon_min = 125
lon_max = 130
lat_min = -5
lat_max = 0

nb_points = 60
dx = (lon_max-lon_min)/nb_points
dy = (lat_max-lat_min)/nb_points

for i in range(nb_points):
        for j in range(nb_points):
                lons.append(lon_min+i*dx)
                lats.append(lat_min+j*dy)

time_step = timedelta(days=1)
o.seed_elements(lons, lats, time=seed_time)

# %% [markdown]
# We can now run OpenDrift. The following cell returns a netcdf and jpeg file you can access in *ARIANE/RES* directory. Caution : the output of the cell is rather long as OpenDrift reports each task.

# %%
print(o)

print("launch run")

o.run(steps=61, time_step=3600*24,outfile="ARIANE/RES/OpenDrift_res_06_08_2015.nc")

print("run finished")
o.plot(filename="ARIANE/RES/OpenDrift_res_06_08_2015.png")
# Out:
# ===========================
# Model:	OceanDrift     (OpenDrift version 1.5.6)
# 	0 active Lagrangian3DArray particles  (0 deactivated, 3600 scheduled)
# -------------------
# Environment variables:
#   -----
#   land_binary_mask
#      1) shape
#      2) ARIANE/DATA/glorys12v1_landmask_v3.nc
#   -----
#   x_sea_water_velocity
#   y_sea_water_velocity
#      1) ARIANE/DATA/glorys12v1_landmask_v3.nc
#   -----
# Readers not added for the following variables:
#   ocean_vertical_diffusivity
#   sea_floor_depth_below_sea_level
#   sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment
#   sea_surface_wave_period_at_variance_spectral_density_maximum
#   sea_surface_wave_significant_height
#   sea_surface_wave_stokes_drift_x_velocity
#   sea_surface_wave_stokes_drift_y_velocity
#   surface_downward_x_stress
#   surface_downward_y_stress
#   turbulent_generic_length_scale
#   turbulent_kinetic_energy
#   upward_sea_water_velocity
#   x_wind
#   y_wind
# ===========================
#
# launch run
# 08:09:36 DEBUG   opendrift.models.basemodel:
# ------------------------------------------------------
# Software and hardware:
#   OpenDrift version 1.5.6
#   Platform: Linux, 4.19-ovh-xxxx-std-ipv6-64
#   125.76339721679688 GB memory
#   48 processors (x86_64)
#   NumPy version 1.20.2
#   SciPy version 1.6.2
#   Matplotlib version 3.4.1
#   NetCDF4 version 1.5.6
#   Xarray version 0.17.0
#   OilLibrary version 1.1.3
#   Python version 3.9.2 | packaged by conda-forge | (default, Feb 21 2021, 05:02:46) [GCC 9.3.0]
# ------------------------------------------------------
#
# 08:09:36 INFO    opendrift.models.basemodel: Fallback values will be used for the following variables which have no readers:
# 08:09:36 INFO    opendrift.models.basemodel: 	x_wind: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	y_wind: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	upward_sea_water_velocity: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	ocean_vertical_diffusivity: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_surface_wave_significant_height: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	surface_downward_x_stress: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	surface_downward_y_stress: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	turbulent_kinetic_energy: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	turbulent_generic_length_scale: 0.000000
# 08:09:36 INFO    opendrift.models.basemodel: 	sea_floor_depth_below_sea_level: 10000.000000
# 08:09:36 DEBUG   opendrift.models.basemodel: Preparing readers for simulation coverage ([77.47216223638658, -52.48108108108108, 177.44450951654312, 47.39774774526422]) and time (2015-06-01 00:00:00 to 2015-08-01 00:00:00)
# 08:09:36 DEBUG   opendrift.models.basemodel: 	Preparing shape
# 08:09:36 DEBUG   opendrift.readers.basereader: Nothing to prepare for shape
# 08:09:36 DEBUG   opendrift.models.basemodel: 	Preparing ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:36 DEBUG   opendrift.readers.basereader: Nothing to prepare for ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:36 INFO    opendrift.models.basemodel: Using existing reader for land_binary_mask
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:36 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:36 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:36 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:36 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:36 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:36 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:36 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:36 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:36 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: 		0 active elements
# 08:09:36 INFO    opendrift.models.basemodel: Moving 278 out of 3600 points from land to water
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:36 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:36 DEBUG   opendrift.models.basemodel: Data needed for 262144 elements
# 08:09:36 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:37 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:37 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 		0 active elements
# 08:09:37 DEBUG   opendrift.models.basemodel: to be seeded: 3600, already seeded 0
# 08:09:37 DEBUG   opendrift.models.basemodel: Released 3600 new elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 INFO    opendrift.models.basemodel: 2015-06-01 00:00:00 - step 1 of 61 - 3600 active elements (0 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 	Outside time coverage of reader.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:37 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:37 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:37 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 		3600 active elements
# 08:09:37 DEBUG   opendrift.models.basemodel: 		-5.0 <- latitude  -> -0.08
# 08:09:37 DEBUG   opendrift.models.basemodel: 		125.0 <- longitude -> 129.97
# 08:09:37 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:37 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.basemodel: No elements to deactivate
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:37 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:37 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:37 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:37 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:37 DEBUG   opendrift.models.basemodel: 3600 active elements (0 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: to be seeded: 0, already seeded 3600
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 INFO    opendrift.models.basemodel: 2015-06-02 00:00:00 - step 2 of 61 - 3600 active elements (0 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Reader time:
# 		2015-06-01 12:00:00 (before)
# 		2015-06-02 12:00:00 (after)
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using eastward_sea_water_velocity to retrieve x_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using northward_sea_water_velocity to retrieve y_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: North is up, no rotation necessary
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking x_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking y_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Fetched env-block (size 84x84x1) for time before (2015-06-01 12:00:00)
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using eastward_sea_water_velocity to retrieve x_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using northward_sea_water_velocity to retrieve y_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: North is up, no rotation necessary
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking x_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking y_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Fetched env-block (size 84x84x1) for time after (2015-06-02 12:00:00)
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-01 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 518 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 53 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 518 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 53 elements, expanding data 2
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating after (2015-06-02 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 518 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 53 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 518 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 53 elements, expanding data 2
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-01 12:00:00, weight 0.50) and
# 		      after (2015-06-02 12:00:00, weight 0.50) in time
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:37 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:37 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:37 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: -0.378084 (min) 0.359563 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: -0.608528 (min) 0.377679 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 		3600 active elements
# 08:09:37 DEBUG   opendrift.models.basemodel: 		-5.0 <- latitude  -> -0.07999999821186066
# 08:09:37 DEBUG   opendrift.models.basemodel: 		125.0 <- longitude -> 129.97000122070312
# 08:09:37 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:37 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.basemodel: No elements to deactivate
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:37 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:37 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:37 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:37 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:37 DEBUG   opendrift.models.basemodel: 3600 active elements (0 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: to be seeded: 0, already seeded 3600
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 INFO    opendrift.models.basemodel: 2015-06-03 00:00:00 - step 3 of 61 - 3600 active elements (0 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3600 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Reader time:
# 		2015-06-02 12:00:00 (before)
# 		2015-06-03 12:00:00 (after)
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using eastward_sea_water_velocity to retrieve x_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using northward_sea_water_velocity to retrieve y_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: North is up, no rotation necessary
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking x_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking y_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Fetched env-block (size 89x88x1) for time after (2015-06-03 12:00:00)
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-02 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 5 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 5 elements, expanding data 1
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating after (2015-06-03 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 527 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 56 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 6 elements, expanding data 3
# 08:09:37 DEBUG   opendrift: NaN values for 527 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 56 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 6 elements, expanding data 3
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-02 12:00:00, weight 0.50) and
# 		      after (2015-06-03 12:00:00, weight 0.50) in time
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:37 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:37 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:37 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: -0.479483 (min) 0.36249 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: -0.554428 (min) 0.383085 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 		3600 active elements
# 08:09:37 DEBUG   opendrift.models.basemodel: 		-5.277758204819629 <- latitude  -> 0.022792954255977646
# 08:09:37 DEBUG   opendrift.models.basemodel: 		124.72265770314424 <- longitude -> 130.16295593960274
# 08:09:37 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:37 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.basemodel: Added status stranded
# 08:09:37 DEBUG   opendrift.models.basemodel: 163 elements scheduled for deactivation (stranded)
# 08:09:37 DEBUG   opendrift.models.basemodel: 	(z: 0.000000 to 0.000000)
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 163 elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 163 values from environment.
# 08:09:37 DEBUG   opendrift.models.basemodel: remove items from profile for z
# 08:09:37 DEBUG   opendrift.models.basemodel: remove items from profile for ocean_vertical_diffusivity
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 163 values from environment_profiles.
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:37 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:37 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:37 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:37 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:37 DEBUG   opendrift.models.basemodel: 3437 active elements (163 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: to be seeded: 0, already seeded 3600
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 INFO    opendrift.models.basemodel: 2015-06-04 00:00:00 - step 4 of 61 - 3437 active elements (163 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3437 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3437 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Reader time:
# 		2015-06-03 12:00:00 (before)
# 		2015-06-04 12:00:00 (after)
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using eastward_sea_water_velocity to retrieve x_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using northward_sea_water_velocity to retrieve y_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: North is up, no rotation necessary
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking x_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking y_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Fetched env-block (size 96x91x1) for time after (2015-06-04 12:00:00)
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-03 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating after (2015-06-04 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 419 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 32 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 419 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 32 elements, expanding data 2
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-03 12:00:00, weight 0.50) and
# 		      after (2015-06-04 12:00:00, weight 0.50) in time
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:37 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:37 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:37 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: -0.600069 (min) 0.323613 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: -0.566864 (min) 0.308162 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: 		3437 active elements
# 08:09:37 DEBUG   opendrift.models.basemodel: 		-5.4752105063704315 <- latitude  -> 0.16544938976358142
# 08:09:37 DEBUG   opendrift.models.basemodel: 		124.39272526646104 <- longitude -> 130.3793715548931
# 08:09:37 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:37 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:37 DEBUG   opendrift.models.basemodel: 45 elements scheduled for deactivation (stranded)
# 08:09:37 DEBUG   opendrift.models.basemodel: 	(z: 0.000000 to 0.000000)
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 45 elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 45 values from environment.
# 08:09:37 DEBUG   opendrift.models.basemodel: remove items from profile for z
# 08:09:37 DEBUG   opendrift.models.basemodel: remove items from profile for ocean_vertical_diffusivity
# 08:09:37 DEBUG   opendrift.models.basemodel: Removed 45 values from environment_profiles.
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:37 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:37 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:37 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:37 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:37 DEBUG   opendrift.models.basemodel: 3392 active elements (208 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: to be seeded: 0, already seeded 3600
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 INFO    opendrift.models.basemodel: 2015-06-05 00:00:00 - step 5 of 61 - 3392 active elements (208 deactivated)
# 08:09:37 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:37 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3392 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:37 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Data needed for 3392 elements
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Fetching variables from ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Reader time:
# 		2015-06-04 12:00:00 (before)
# 		2015-06-05 12:00:00 (after)
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using eastward_sea_water_velocity to retrieve x_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: Using northward_sea_water_velocity to retrieve y_sea_water_velocity
# 08:09:37 DEBUG   opendrift.readers.reader_netCDF_CF_generic: North is up, no rotation necessary
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking x_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Checking y_sea_water_velocity for invalid values
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Fetched env-block (size 102x96x1) for time after (2015-06-05 12:00:00)
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-04 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating after (2015-06-05 12:00:00) in space  (linearNDFast)
# 08:09:37 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:37 DEBUG   opendrift: NaN values for 363 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 22 elements, expanding data 2
# 08:09:37 DEBUG   opendrift: NaN values for 363 elements, expanding data 1
# 08:09:37 DEBUG   opendrift: NaN values for 22 elements, expanding data 2
# 08:09:37 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-06-04 12:00:00, weight 0.50) and
# 		      after (2015-06-05 12:00:00, weight 0.50) in time
# 08:09:37 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:37 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:37 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:37 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:38 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:38 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:38 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:38 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: -0.700418 (min) 0.2214 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: -0.646746 (min) 0.275228 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:38 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: 		3392 active elements
# 08:09:38 DEBUG   opendrift.models.basemodel: 		-5.70291427000132 <- latitude  -> 0.3061315170209289
# 08:09:38 DEBUG   opendrift.models.basemodel: 		124.04604114180837 <- longitude -> 130.56558439685992
# 08:09:38 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:38 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:38 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:38 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:38 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:38 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:38 DEBUG   opendrift.models.basemodel: 29 elements scheduled for deactivation (stranded)
# 08:09:38 DEBUG   opendrift.models.basemodel: 	(z: 0.000000 to 0.000000)
# 08:09:38 DEBUG   opendrift.models.basemodel: Removed 29 elements.
# 08:09:38 DEBUG   opendrift.models.basemodel: Removed 29 values from environment.
# 08:09:38 DEBUG   opendrift.models.basemodel: remove items from profile for z
# 08:09:38 DEBUG   opendrift.models.basemodel: remove items from profile for ocean_vertical_diffusivity
# 08:09:38 DEBUG   opendrift.models.basemodel: Removed 29 values from environment_profiles.
# 08:09:38 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:38 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:38 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:38 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:38 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:38 DEBUG   opendrift.models.basemodel: 3363 active elements (237 deactivated)
# 08:09:38 DEBUG   opendrift.models.basemodel: to be seeded: 0, already seeded 3600
# 08:09:38 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:38 INFO    opendrift.models.basemodel: 2015-06-06 00:00:00 - step 6 of 61 - 3363 active elements (237 deactivated)
# 08:09:38 DEBUG   opendrift.models.basemodel: 0 elements scheduled.
# 08:09:38 DEBUG   opendrift.models.basemodel: ======================================================================
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Data needed for 3363 elements
# 08:09:38 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:38 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:38 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:38 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:38 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Variable group ['x_sea_water_velocity', 'y_sea_water_velocity']
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Calling reader ARIANE/DATA/glorys12v1_landmask_v3.nc
# 08:09:38 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:38 DEBUG   opendrift.models.basemodel: Data needed for 3363 elements
# ...
# 08:09:44 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-07-30 12:00:00) in space  (linearNDFast)
# 08:09:44 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:44 DEBUG   opendrift.readers.basereader.structured: Interpolating after (2015-07-31 12:00:00) in space  (linearNDFast)
# 08:09:44 DEBUG   opendrift.readers.interpolation.structured: Initialising interpolator.
# 08:09:44 DEBUG   opendrift: NaN values for 69 elements, expanding data 1
# 08:09:44 DEBUG   opendrift: NaN values for 9 elements, expanding data 2
# 08:09:44 DEBUG   opendrift: NaN values for 69 elements, expanding data 1
# 08:09:44 DEBUG   opendrift: NaN values for 9 elements, expanding data 2
# 08:09:44 DEBUG   opendrift.readers.basereader.structured: Interpolating before (2015-07-30 12:00:00, weight 0.50) and
# 		      after (2015-07-31 12:00:00, weight 0.50) in time
# 08:09:44 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:44 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:44 DEBUG   opendrift.models.basemodel: Creating empty dictionary for profiles not profided by any reader: ['ocean_vertical_diffusivity']
# 08:09:44 DEBUG   opendrift.models.basemodel:       Using fallback value 0 for ocean_vertical_diffusivity for all profiles
# 08:09:44 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:44 DEBUG   opendrift.models.basemodel:     x_sea_water_velocity: -0.709898 (min) 1.35487 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     y_sea_water_velocity: -0.705583 (min) 1.02298 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     x_wind: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     y_wind: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     upward_sea_water_velocity: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     ocean_vertical_diffusivity: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_surface_wave_significant_height: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_x_velocity: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_surface_wave_stokes_drift_y_velocity: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_surface_wave_period_at_variance_spectral_density_maximum: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     surface_downward_x_stress: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     surface_downward_y_stress: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     turbulent_kinetic_energy: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     turbulent_generic_length_scale: 0 (min) 0 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     sea_floor_depth_below_sea_level: 10000 (min) 10000 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: 		2545 active elements
# 08:09:44 DEBUG   opendrift.models.basemodel: 		-13.249674674822835 <- latitude  -> 6.375759848610496
# 08:09:44 DEBUG   opendrift.models.basemodel: 		110.54392190864031 <- longitude -> 159.03039478325522
# 08:09:44 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:44 DEBUG   opendrift.models.physics_methods: Calculating Hs from wind, min: 0.000000, mean: 0.000000, max: 0.000000
# 08:09:44 DEBUG   opendrift.models.physics_methods: Calculating wave period Tm02 from wind
# 08:09:44 DEBUG   opendrift.models.physics_methods:    min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:44 DEBUG   opendrift.models.physics_methods: Calculating wave period from wind, min: 1.256637, mean: 1.256637, max: 1.256637
# 08:09:44 DEBUG   opendrift.models.basemodel: 16 elements scheduled for deactivation (stranded)
# 08:09:44 DEBUG   opendrift.models.basemodel: 	(z: 0.000000 to 0.000000)
# 08:09:44 DEBUG   opendrift.models.basemodel: Removed 16 elements.
# 08:09:44 DEBUG   opendrift.models.basemodel: Removed 16 values from environment.
# 08:09:44 DEBUG   opendrift.models.basemodel: remove items from profile for z
# 08:09:44 DEBUG   opendrift.models.basemodel: remove items from profile for ocean_vertical_diffusivity
# 08:09:44 DEBUG   opendrift.models.basemodel: Removed 16 values from environment_profiles.
# 08:09:44 DEBUG   opendrift.models.basemodel: Calling OceanDrift.update()
# 08:09:44 DEBUG   opendrift.models.physics_methods: No wind for wind-sheared ocean drift
# 08:09:44 DEBUG   opendrift.models.physics_methods: No Stokes drift velocity available
# 08:09:44 DEBUG   opendrift.models.oceandrift: No vertical advection for elements at surface
# 08:09:44 DEBUG   opendrift.models.basemodel: Horizontal diffusivity is 0, no random walk.
# 08:09:44 DEBUG   opendrift.models.basemodel: 2529 active elements (1071 deactivated)
# 08:09:44 DEBUG   opendrift.models.basemodel: Cleaning up
# 08:09:44 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: Variable group ['land_binary_mask']
# 08:09:44 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: Calling reader shape
# 08:09:44 DEBUG   opendrift.models.basemodel: ----------------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: Data needed for 2529 elements
# 08:09:44 DEBUG   opendrift.readers.basereader.variables: Fetching variables from shape
# 08:09:44 DEBUG   opendrift.readers.basereader.continuous: Fetched env-before
# 08:09:44 DEBUG   opendrift.readers.basereader.variables: Checking land_binary_mask for invalid values
# 08:09:44 DEBUG   opendrift.readers.basereader.variables: Reader projection is latlon - rotation of vectors is not needed.
# 08:09:44 DEBUG   opendrift.models.basemodel: Obtained data for all elements.
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: Finished processing all variable groups
# 08:09:44 DEBUG   opendrift.models.basemodel: ------------ SUMMARY -------------
# 08:09:44 DEBUG   opendrift.models.basemodel:     land_binary_mask: 0 (min) 1 (max)
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: 		2529 active elements
# 08:09:44 DEBUG   opendrift.models.basemodel: 		-13.281691679779021 <- latitude  -> 6.307609111683681
# 08:09:44 DEBUG   opendrift.models.basemodel: 		110.43066450142052 <- longitude -> 159.85761235329997
# 08:09:44 DEBUG   opendrift.models.basemodel: 		z = 0.0
# 08:09:44 DEBUG   opendrift.models.basemodel: ---------------------------------
# 08:09:44 DEBUG   opendrift.models.basemodel: 22 elements scheduled for deactivation (stranded)
# 08:09:44 DEBUG   opendrift.models.basemodel: 	(z: 0.000000 to 0.000000)
# 08:09:44 DEBUG   opendrift.models.basemodel: Writing and closing output file: ARIANE/RES/OpenDrift_res_06_08_2015.nc
# 08:09:44 INFO    opendrift.export.io_netcdf: Wrote 62 steps to file ARIANE/RES/OpenDrift_res_06_08_2015.nc
# 08:09:44 DEBUG   opendrift.export.io_netcdf: Making netCDF file CDM compliant with fixed dimensions
# 08:09:44 DEBUG   opendrift.export.io_netcdf: Importing from ARIANE/RES/OpenDrift_res_06_08_2015.nc
# 08:09:45 DEBUG   opendrift.models.basemodel: Removed 1093 elements.
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: general:use_auto_landmask -> False
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: general:coastline_action -> stranding
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: general:time_step_minutes -> 60
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: general:time_step_output_minutes -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:ocean_only -> True
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:number -> 1
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:max_age_seconds -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:advection_scheme -> euler
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:current_uncertainty -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:current_uncertainty_uniform -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:horizontal_diffusivity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:wind_uncertainty -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:relative_wind -> False
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:deactivate_north_of -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:deactivate_south_of -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:deactivate_east_of -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:deactivate_west_of -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:origin_marker -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:z -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:wind_drift_factor -> 0.02
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:terminal_velocity -> 0.0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:x_wind -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:x_wind -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:y_wind -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:y_wind -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:constant:land_binary_mask -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: environment:fallback:land_binary_mask -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:vertical_advection -> True
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:vertical_mixing -> False
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: vertical_mixing:timestep -> 60
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: vertical_mixing:TSprofiles -> False
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:wind_drift_depth -> 0.1
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:stokes_drift -> True
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 08:09:45 DEBUG   opendrift.export.io_netcdf: Setting imported config: seed:seafloor -> False
# run finished
# 08:09:56 INFO    opendrift.models.basemodel: Time to make plot: 0:00:11.536662
# (<GeoAxesSubplot:title={'center':'OpenDrift - OceanDrift\n2015-06-01 00:00 to 2015-08-01 00:00 UTC (62 steps)'}>,
#  <module 'matplotlib.pyplot' from '/opt/anaconda3/envs/opendrift/lib/python3.9/site-packages/matplotlib/pyplot.py'>)

# %% [markdown]
# <img src="https://i.imgur.com/7DEE3MT.png" align=center>

# %% [markdown]
# You can see in the map above the trajectory of the particules, the coasts where some have landed and where the other ones are drifting.

# %%
path_file1 = 'ARIANE/RES/OpenDrift_res_06_08_2015.nc'
file1 = xr.open_dataset(path_file1)
print(file1)
# Out:
# <xarray.Dataset>
# Dimensions:                                                                              (time: 62, trajectory: 3600)
# Coordinates:
#   * trajectory                                                                           (trajectory) int32 ...
#   * time                                                                                 (time) datetime64[ns] ...
#     lon                                                                                  (trajectory, time) float32 ...
#     lat                                                                                  (trajectory, time) float32 ...
# Data variables: (12/24)
#     status                                                                               (trajectory, time) int32 ...
#     moving                                                                               (trajectory, time) int32 ...
#     age_seconds                                                                          (trajectory, time) float32 ...
#     origin_marker                                                                        (trajectory, time) int16 ...
#     z                                                                                    (trajectory, time) float32 ...
#     wind_drift_factor                                                                    (trajectory, time) float32 ...
#     ...                                                                                   ...
#     surface_downward_x_stress                                                            (trajectory, time) float32 ...
#     surface_downward_y_stress                                                            (trajectory, time) float32 ...
#     turbulent_kinetic_energy                                                             (trajectory, time) float32 ...
#     turbulent_generic_length_scale                                                       (trajectory, time) float32 ...
#     sea_floor_depth_below_sea_level                                                      (trajectory, time) float32 ...
#     land_binary_mask                                                                     (trajectory, time) float32 ...
# Attributes: (12/111)
#     Conventions:                                                             ...
#     standard_name_vocabulary:                                                ...
#     featureType:                                                             ...
#     history:                                                                 ...
#     source:                                                                  ...
#     model_url:                                                               ...
#     ...                                                                                                               ...
#     geospatial_lat_resolution:                                               ...
#     geospatial_lon_min:                                                      ...
#     geospatial_lon_max:                                                      ...
#     geospatial_lon_units:                                                    ...
#     geospatial_lon_resolution:                                               ...
#     runtime:                                                                 ...

# %%
dates = file1['time'].data
for i in range(len(dates)):
    data_crs = ccrs.PlateCarree()
    projection=ccrs.PlateCarree(central_longitude=0)
    f = plt.figure(figsize=(12, 12))
    ax = plt.axes(projection=projection)
    
    ax.coastlines()
    ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
    ax.add_feature(cfeature.LAND, zorder=100, edgecolor='k')
    ax.set_extent([90, 160, -20, 20],crs=ccrs.PlateCarree())
    
    ax.scatter(file1['lon'][:,i],file1['lat'][:,i],c='tab:red',s=1)
    
    ax.set_title('OpenDrift simulation - '+ np.datetime_as_string(dates[i], unit='D'),fontsize=24)
    plt.savefig('ARIANE/FIGURES/OpenDrift_trajectory_'+str(i).zfill(3)+'.png')
